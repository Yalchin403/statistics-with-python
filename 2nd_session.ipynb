# %%
import pandas as pd
import seaborn as sb


data_frame = pd.read_csv("/mnt/762af900-5e3c-4ea0-aae0-092233720e98/Downloads/auto-mpg.csv")
data_frame
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0         130    3504          12.0
# 1    15.0          8         350.0         165    3693          11.5
# 2    18.0          8         318.0         150    3436          11.0
# 3    16.0          8         304.0         150    3433          12.0
# 4    17.0          8         302.0         140    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0          86    2790          15.6
# 394  44.0          4          97.0          52    2130          24.6
# 395  32.0          4         135.0          84    2295          11.6
# 396  28.0          4         120.0          79    2625          18.6
# 397  31.0          4         119.0          82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
sb.boxplot(data=data_frame, x = data_frame['horsepower'])
# Out:
# <AxesSubplot:xlabel='horsepower'>

# %%
data_frame["horsepower"].describe()
# Out:
# count    398.000000
# mean     104.183417
# std       38.489215
# min       12.000000
# 25%       75.250000
# 50%       94.500000
# 75%      125.000000
# max      230.000000
# Name: horsepower, dtype: float64

# %%
q1 = data_frame["horsepower"].quantile(0.25)
q1
q3 = data_frame["horsepower"].quantile(0.75)
q3

iqr = q3 - q1
iqr

upper_boundary = q3 + 1.5 * iqr
lower_boundary = q1 - 1.5 * iqr

upper_boundary
lower_boundary
# Out:
# 0.625

# %%
filter = data_frame["horsepower"] < upper_boundary
data_frame2 = data_frame[filter]
data_frame2
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0         130    3504          12.0
# 1    15.0          8         350.0         165    3693          11.5
# 2    18.0          8         318.0         150    3436          11.0
# 3    16.0          8         304.0         150    3433          12.0
# 4    17.0          8         302.0         140    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0          86    2790          15.6
# 394  44.0          4          97.0          52    2130          24.6
# 395  32.0          4         135.0          84    2295          11.6
# 396  28.0          4         120.0          79    2625          18.6
# 397  31.0          4         119.0          82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
filter = data_frame2["horsepower"] > lower_boundary
data_frame3 = data_frame2[filter]
data_frame3
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0         130    3504          12.0
# 1    15.0          8         350.0         165    3693          11.5
# 2    18.0          8         318.0         150    3436          11.0
# 3    16.0          8         304.0         150    3433          12.0
# 4    17.0          8         302.0         140    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0          86    2790          15.6
# 394  44.0          4          97.0          52    2130          24.6
# 395  32.0          4         135.0          84    2295          11.6
# 396  28.0          4         120.0          79    2625          18.6
# 397  31.0          4         119.0          82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
from random import randrange
import random 
import string


def dict_gen(n, m):
    dict_ = dict()
    for i in range(n):
        key = f"key{i}"
        dict_[key] = []
        for i in range(m):
            letters = string.ascii_lowercase
            result_str = ''.join(random.choice(letters) for i in range(6))
            dict_[key].append(result_str)
            
    return dict_

dict_ = dict_gen(5, 20)
data_frame = pd.DataFrame(dict_)
data_frame
# Out:
#       key0    key1    key2    key3    key4
# 0   nsxqnv  vosupg  cexyda  qmlidb  oizsft
# 1   jikkzq  fvdany  idzkei  bjfdch  ibqtyc
# 2   vkwypl  wlkxph  qwkhjk  mmaedp  lhxtnu
# 3   fmizso  jjlmfa  tmquaw  yprolg  bnfbdx
# 4   mysizo  sshplv  fkmglp  shegyg  mnkqbu
# 5   xfnxym  irgjsf  ibnppd  bvenho  mdesfc
# 6   tgyqdy  wexsyi  xpxdcw  sqykjg  txpxqm
# 7   opxxcc  khhjxi  dgfmjx  wrqmns  yrdues
# 8   ewpodk  bhyzzy  tqmnij  iwoptp  wfzgxq
# 9   iznhpf  gnfoqg  pxengq  ueldxb  cbpoin
# 10  gifeqc  vpvywl  dgchhq  lxhkag  qhobdw
# 11  zyzlsw  mtwroi  tjgyqn  wmitkq  oqgwso
# 12  xwtyqc  tbeimn  cnukem  wlouci  tyiydx
# 13  gdallp  osbdgz  gwshlr  gpgncl  xrsefy
# 14  bxquek  nomcxj  nppoba  cbgrlc  laydky
# 15  ihbbvd  cmklbv  qmptlc  jddtxs  zcpebt
# 16  pzoxbe  movjkm  qhrtkl  ltcrgl  yfhonm
# 17  epxces  mvtxwc  vjkvad  stspep  kpdggb
# 18  dwcequ  eptpnj  qclrah  tqszhp  htafek
# 19  takriu  zhhmef  ugzhnc  aafxnd  grexmt
